# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt  
# Creating a black image with 3 channels
# RGB and unsigned int datatype
img = np.zeros((600,600), dtype = "uint8")
points = np.array([[160, 130], [350, 130], [250, 300]])
pointsx = np.array([[30, 30], [170, 30], [170, 170],[30,170]])
#img = cv2.fillPoly(img, pts=[points], color=255)
#img = cv2.circle(img, (50,50), 70, color=255, thickness=-1)
img = cv2.fillPoly(img, pts=[pointsx], color=255)
print(np.amax(img),np.amin(img),set(img.ravel()))
plt.imshow(img, cmap='gray')
cv2.imwrite('test.png',img)
# Out:
# 255 0 {0, 255}
# True

# %%
img1 = cv2.imread('test.png',cv2.IMREAD_GRAYSCALE)
print(np.shape(img1))
plt.imshow(img1, cmap='gray')
# Out:
# (600, 600)

# %%
print(np.amax(img1),np.amin(img1),set(img1.ravel()))
# Out:
# 255 0 {0, 255}

# %%
import math
def rotateShift(pos,theta,xs,ys):
    x = pos[0]
    y = pos[1]
    x1 = x*np.cos(theta) - y*np.sin(theta) + xs
    y1 = y*np.cos(theta) + x*np.sin(theta) + ys
    return [x1,y1]
rotateShift([2,3],math.pi,1,1)
# Out:
# [-1.0000000000000004, -1.9999999999999996]

# %%
print(np.cos(3.142))
# Out:
# -0.9999999170344522

# %%
print(7//3,7%3)
# Out:
# 2 1

# %%
import random
num = random.random()
print(num)
# Out:
# 0.7910968402946174

# %%
import math
import cv2
import numpy as np
import random
import matplotlib.pyplot as plt
def rotateShift(pos,theta,xs,ys):
    x = pos[0]
    y = pos[1]
    x1 = int(x*np.cos(theta) - y*np.sin(theta) + xs)
    y1 = int(y*np.cos(theta) + x*np.sin(theta) + ys)
    return [x1,y1]

def drawSquare(img,c,theta,col):
    xs = (c%3)*200
    ys = (c//3)*200
    x0 = 100
    y0 = 100
    #theta = 2*math.pi*random.random()
    pos1 = rotateShift([30-x0,30-y0],theta,x0+xs,y0+ys)
    pos2 = rotateShift([170-x0,30-y0],theta,x0+xs,y0+ys)
    pos3 = rotateShift([170-x0,170-y0],theta,x0+xs,y0+ys)
    pos4 = rotateShift([30-x0,170-y0],theta,x0+xs,y0+ys)
    pointsx = np.array([pos1,pos2,pos3,pos4])
    #print(pointsx)
    #print(np.shape(pointsx))
    img = cv2.fillPoly(img, pts=[pointsx], color=col)
    return img

def drawTriangle(img,c,theta,col):
    xs = (c%3)*200
    ys = (c//3)*200
    x0 = 100
    y0 = 100
    #theta = 2*math.pi*random.random()
    pos1 = rotateShift([100-x0,195-y0],theta,x0+xs,y0+ys)
    pos2 = rotateShift([18-x0,53-y0],theta,x0+xs,y0+ys)
    pos3 = rotateShift([182-x0,53-y0],theta,x0+xs,y0+ys)
    pointsx = np.array([pos1,pos2,pos3])
    img = cv2.fillPoly(img, pts=[pointsx], color=col)
    return img

def drawCircle(img,c,rad,col):
    xs = (c%3)*200
    ys = (c//3)*200
    x0 = 100
    y0 = 100
    #r = int(90 + 10*np.random.random())
    img = cv2.circle(img, (x0+xs,y0+ys), rad, color=col, thickness=-1)
    return img

# %%
img = np.zeros((600,600), dtype = "uint8")

theta1 = 2*math.pi*random.random()
col1 = int(120+50*random.random())
img = drawSquare(img,8,theta1,col1)

theta2 = 2*math.pi*random.random()
col2 = int(120+50*random.random())
img = drawTriangle(img,0,theta2,col2)

rad = int(90 + 10*random.random())
col3 = int(120+50*random.random())
img = drawCircle(img,3,rad,col3)
print(np.amax(img),np.amin(img),set(img.ravel()))
plt.imshow(img, cmap='gray')
# Out:
# 164 0 {0, 122, 164, 135}

# %%
r = 95
a = int(r*np.cos(math.pi/3))
b = int(r*np.sin(math.pi/3))
print(100-a)
print(100-b)
print(100+b)
print(a)
print(b)
# Out:
# 53
# 18
# 182
# 47
# 82

# %%
seq = list(np.arange(0,9))
print(seq)
n = 3

random.sample(seq, n)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# [2, 7, 8]

# %%
import matplotlib.pyplot as plt
import RandomShape
import numpy as np
img,mask = RandomShape.threeShapeSetA()
print(np.amax(img),np.amin(img),set(img.ravel()))
print(np.amax(mask),np.amin(mask),set(mask.ravel()))
plt.imshow(img, cmap='gray')
plt.show()
plt.imshow(mask, cmap='gray')
plt.show()
# Out:
# 168 0 {0, 125, 168, 143}
# 255 0 {0, 255}

# %%
import matplotlib.pyplot as plt
import RandomShape
import numpy as np
img,mask = RandomShape.threeShapeSetB()
print(np.amax(img),np.amin(img),set(img.ravel()))
print(np.amax(mask),np.amin(mask),set(mask.ravel()))
plt.imshow(img, cmap='gray')
plt.show()
plt.imshow(mask, cmap='gray')
plt.show()
# Out:
# 161 0 {0, 161, 139, 136}
# 255 0 {0, 255}

# %%
import matplotlib.pyplot as plt
import RandomShape
import numpy as np
import cv2
import os
from tqdm import tqdm
os.mkdir('./SetA')
os.mkdir('./SetA_Mask')
path_img = './SetA/'
path_mask = './SetA_Mask/'
for i in tqdm(range(1000)):
    fname = 'A'+str(i).zfill(3)+'.png'
    img,mask = RandomShape.threeShapeSetA()
    cv2.imwrite(path_img+fname,img)
    cv2.imwrite(path_mask+fname,mask)
# Out:
#   5%|▍         | 49/1000 [00:00<00:01, 483.00it/s]
# ./SetA/A000.png
# ./SetA/A001.png
# ./SetA/A002.png
# ./SetA/A003.png
# ./SetA/A004.png
# ./SetA/A005.png
# ./SetA/A006.png
# ./SetA/A007.png
# ./SetA/A008.png
# ./SetA/A009.png
# ./SetA/A010.png
# ./SetA/A011.png
# ./SetA/A012.png
# ./SetA/A013.png
# ./SetA/A014.png
# ./SetA/A015.png
# ./SetA/A016.png
# ./SetA/A017.png
# ./SetA/A018.png
# ./SetA/A019.png
# ./SetA/A020.png
# ./SetA/A021.png
# ./SetA/A022.png
# ./SetA/A023.png
# ./SetA/A024.png
# ./SetA/A025.png
# ./SetA/A026.png
# ./SetA/A027.png
# ./SetA/A028.png
# ./SetA/A029.png
# ./SetA/A030.png
# ./SetA/A031.png
# ./SetA/A032.png
# ./SetA/A033.png
# ./SetA/A034.png
# ./SetA/A035.png
# ./SetA/A036.png
# ./SetA/A037.png
# ./SetA/A038.png
# ./SetA/A039.png
# ./SetA/A040.png
# ./SetA/A041.png
# ./SetA/A042.png
# ./SetA/A043.png
# ./SetA/A044.png
# ./SetA/A045.png
# ./SetA/A046.png
# ./SetA/A047.png
# ./SetA/A048.png
# ./SetA/A049.png
# ./SetA/A050.png
# ./SetA/A051.png
# ...

# %%
import matplotlib.pyplot as plt
import RandomShape
import numpy as np
import cv2
from tqdm import tqdm
os.mkdir('./SetB')
os.mkdir('./SetB_Mask')
path_img = './SetB/'
path_mask = './SetB_Mask/'
for i in tqdm(range(1000)):
    fname = 'B'+str(i).zfill(3)+'.png'
    img,mask = RandomShape.threeShapeSetB()
    cv2.imwrite(path_img+fname,img)
    cv2.imwrite(path_mask+fname,mask)
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 9625.00it/s]

# %%
def rotateShift(pos,theta,xs,ys):
    x = pos[0]
    y = pos[1]
    x1 = int(x*np.cos(theta) - y*np.sin(theta) + xs)
    y1 = int(y*np.cos(theta) + x*np.sin(theta) + ys)
    return [x1,y1]

def drawSquareNew(img,theta,col):
    x0 = 300
    y0 = 300
    xs = 0
    ys = 0
    #theta = 2*math.pi*random.random()
    pos1 = rotateShift([100-x0,100-y0],theta,x0+xs,y0+ys)
    pos2 = rotateShift([100-x0,500-y0],theta,x0+xs,y0+ys)
    pos3 = rotateShift([500-x0,500-y0],theta,x0+xs,y0+ys)
    pos4 = rotateShift([500-x0,100-y0],theta,x0+xs,y0+ys)
    pointsx = np.array([pos1,pos2,pos3,pos4])
    #print(pointsx)
    #print(np.shape(pointsx))
    img = cv2.fillPoly(img, pts=[pointsx], color=col)
    return img

def drawTriangleNew(img,theta,col):
    xs = 0
    ys = 0
    x0 = 300
    y0 = 300
    #theta = 2*math.pi*random.random()
    pos1 = rotateShift([100-x0,100-y0],theta,x0+xs,y0+ys)
    pos2 = rotateShift([100-x0,500-y0],theta,x0+xs,y0+ys)
    pos3 = rotateShift([500-x0,500-y0],theta,x0+xs,y0+ys)
    pointsx = np.array([pos1,pos2,pos3])
    img = cv2.fillPoly(img, pts=[pointsx], color=col)
    return img

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt 
import math
import random
img = np.zeros((600,600), dtype = "uint8")
theta1 = 2*math.pi*random.random()
col1 = int(120+50*random.random())
img = drawTriangleNew(img,theta1,col1)
plt.imshow(img)

# %%
import matplotlib.pyplot as plt
import RandomShape
import numpy as np
import cv2
from tqdm import tqdm
os.mkdir('./SetC')
os.mkdir('./SetC_Mask')
path_img = './ShapeDatasetsNew/SetC/'
path_mask = './ShapeDatasetsNew/SetC_Mask/'
for i in tqdm(range(1000)):
    fname = 'C'+str(i).zfill(3)+'.png'
    img,mask = RandomShape.singleShapeSetC()
    cv2.imwrite(path_img+fname,img)
    cv2.imwrite(path_mask+fname,mask)
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 9057.25it/s]

# %%
import matplotlib.pyplot as plt
import RandomShape
import numpy as np
import cv2
from tqdm import tqdm
os.mkdir('./SetD')
os.mkdir('./SetD_Mask')
path_img = './ShapeDatasetsNew/SetD/'
path_mask = './ShapeDatasetsNew/SetD_Mask/'
for i in tqdm(range(1000)):
    fname = 'D'+str(i).zfill(3)+'.png'
    img,mask = RandomShape.singleShapeSetD()
    cv2.imwrite(path_img+fname,img)
    cv2.imwrite(path_mask+fname,mask)
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 11021.11it/s]

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt  
# Creating a black image with 3 channels
# RGB and unsigned int datatype
img = np.zeros((600,600), dtype = "uint8")
points = np.array([[160, 130], [350, 130], [250, 300]])
pointsx = np.array([[30, 30], [170, 30], [170, 170],[30,170]])
#img = cv2.fillPoly(img, pts=[points], color=255)
#img = cv2.circle(img, (50,50), 70, color=255, thickness=-1)
img = cv2.fillPoly(img, pts=[pointsx], color=255)
print(np.amax(img),np.amin(img),set(img.ravel()))
plt.imshow(img)
cv2.imwrite('test.png',img)
# Out:
# 255 0 {0, 255}
# True

# %%
import matplotlib.pyplot as plt
import RandomShape
import numpy as np
import cv2
import os
import shutil
from tqdm import tqdm
os.mkdir('./SetE')
os.mkdir('./SetE_Mask')
path_img = './SetE/'
path_mask = './SetE_Mask/'
for i in tqdm(range(1000)):
    fname = 'D'+str(i).zfill(3)+'.png'
    img,mask = RandomShape.singleShapeSetE()
    cv2.imwrite(path_img+fname,img)
    cv2.imwrite(path_mask+fname,mask)
# Out:
# 100%|██████████| 1000/1000 [00:01<00:00, 515.28it/s]

# %%
import matplotlib.pyplot as plt
import RandomShape
import numpy as np
import cv2
import os
import shutil
from tqdm import tqdm
os.mkdir('./SetF')
os.mkdir('./SetF_Mask')
path_img = './SetF/'
path_mask = './SetF_Mask/'
for i in tqdm(range(1000)):
    fname = 'D'+str(i).zfill(3)+'.png'
    img,mask = RandomShape.singleShapeSetF()
    cv2.imwrite(path_img+fname,img)
    cv2.imwrite(path_mask+fname,mask)
# Out:
# 100%|██████████| 1000/1000 [00:01<00:00, 580.07it/s]

# %%
import matplotlib.pyplot as plt
import RandomShape
import numpy as np
import cv2
import os
import shutil
from tqdm import tqdm
shutil.rmtree('./SetA_large')
shutil.rmtree('./SetA_large_Mask')
os.mkdir('./SetA_large')
os.mkdir('./SetA_large_Mask')
path_img = './SetA_large/'
path_mask = './SetA_large_Mask/'
for i in tqdm(range(1000)):
    fname = 'D'+str(i).zfill(3)+'.png'
    img,mask = RandomShape.threeShapeSetA_large()
    cv2.imwrite(path_img+fname,img)
    cv2.imwrite(path_mask+fname,mask)
# Out:
# 100%|██████████| 1000/1000 [00:01<00:00, 673.26it/s]

# %%
import matplotlib.pyplot as plt
import RandomShape
import numpy as np
import cv2
import os
import shutil
from tqdm import tqdm
shutil.rmtree('./SetB_large')
shutil.rmtree('./SetB_large_Mask')
os.mkdir('./SetB_large')
os.mkdir('./SetB_large_Mask')
path_img = './SetB_large/'
path_mask = './SetB_large_Mask/'
for i in tqdm(range(1000)):
    fname = 'D'+str(i).zfill(3)+'.png'
    img,mask = RandomShape.threeShapeSetB_large()
    cv2.imwrite(path_img+fname,img)
    cv2.imwrite(path_mask+fname,mask)
# Out:
# 100%|██████████| 1000/1000 [00:01<00:00, 715.53it/s]

# %%
import matplotlib.pyplot as plt
import RandomShape
import numpy as np
import cv2
import os
import shutil
from tqdm import tqdm
# shutil.rmtree('./SetA_contour')
# shutil.rmtree('./SetA_contour_Mask')
os.mkdir('./SetA_contour')
os.mkdir('./SetA_contour_Mask')
path_img = './SetA_contour/'
path_mask = './SetA_contour_Mask/'
for i in tqdm(range(1000)):
    fname = 'D'+str(i).zfill(3)+'.png'
    img,mask = RandomShape.threeShapeSetA_contour()
    
    cv2.imwrite(path_img+fname,img)
    cv2.imwrite(path_mask+fname,mask)
# Out:
# 100%|██████████| 1000/1000 [00:01<00:00, 636.81it/s]

# %%
import matplotlib.pyplot as plt
import RandomShape
import numpy as np
import cv2
import os
import shutil
from tqdm import tqdm
# shutil.rmtree('./SetB_contour')
# shutil.rmtree('./SetB_contour_Mask')
os.mkdir('./SetB_contour')
os.mkdir('./SetB_contour_Mask')
path_img = './SetB_contour/'
path_mask = './SetB_contour_Mask/'
for i in tqdm(range(1000)):
    fname = 'D'+str(i).zfill(3)+'.png'
    img,mask = RandomShape.threeShapeSetB_contour()
    
    cv2.imwrite(path_img+fname,img)
    cv2.imwrite(path_mask+fname,mask)
# Out:
# 100%|██████████| 1000/1000 [00:01<00:00, 636.71it/s]

# %%
import matplotlib.pyplot as plt
import RandomShape
import numpy as np
import cv2
import os
import shutil
from tqdm import tqdm
# shutil.rmtree('./SetA_large_contour')
# shutil.rmtree('./SetA__large_contour_Mask')
os.mkdir('./SetA_large_contour')
os.mkdir('./SetA__large_contour_Mask')
path_img = './SetA_large_contour/'
path_mask = './SetA__large_contour_Mask/'
for i in tqdm(range(1000)):
    fname = 'D'+str(i).zfill(3)+'.png'
    img,mask = RandomShape.threeShapeSetA_large_contour()
    cv2.imwrite(path_img+fname,img)
    cv2.imwrite(path_mask+fname,mask)
# Out:
# 100%|██████████| 1000/1000 [00:01<00:00, 584.77it/s]

# %%
import matplotlib.pyplot as plt
import RandomShape
import numpy as np
import cv2
import os
import shutil
from tqdm import tqdm
# shutil.rmtree('./SetB_large_contour')
# shutil.rmtree('./SetB__large_contour_Mask')
os.mkdir('./SetB_large_contour')
os.mkdir('./SetB__large_contour_Mask')
path_img = './SetB_large_contour/'
path_mask = './SetB__large_contour_Mask/'
for i in tqdm(range(1000)):
    fname = 'D'+str(i).zfill(3)+'.png'
    img,mask = RandomShape.threeShapeSetB_large_contour()
    cv2.imwrite(path_img+fname,img)
    cv2.imwrite(path_mask+fname,mask)
# Out:
# 100%|██████████| 1000/1000 [00:01<00:00, 593.45it/s]
