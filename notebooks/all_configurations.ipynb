# %% [markdown]
# # Configurations
#
# See the exact layers and parameters of each configuration.
#
# > NOTE: This code is based on an outdated version of the UNet model and its configurations of and will therefore not run without errors.

# %%
from unet import UNet
from utils.config import load_config
from trf import compute_trf

# %%
config = load_config("trf54")
model = UNet(config)
_ = compute_trf(model, 576, print_output=True)
# Out:
# -----------------------------------------------
# UNet wit configuration:     trf54
# Total number of parameters: 31013720
# ...
# layer  type             max_trf_size skip conn.
# ...
#     0  input layer                 1
#
# EncoderBlock
#     1  Conv2d                      2
#     2  BatchNorm2d                 2
#     3  ReLU                        2
#     4  Conv2d                      3
#     5  BatchNorm2d                 3
#     6  ReLU                        3      1 OUT
#     7  MaxPool2d                   4
#
# EncoderBlock
#     8  Conv2d                      6
#     9  BatchNorm2d                 6
#    10  ReLU                        6
#    11  Conv2d                      8
#    12  BatchNorm2d                 8
#    13  ReLU                        8      2 OUT
#    14  MaxPool2d                  10
#
# EncoderBlock
#    15  Conv2d                     14
#    16  BatchNorm2d                14
#    17  ReLU                       14
#    18  Conv2d                     18
# ...

# %%
config = load_config("trf100")
model = UNet(config)
_ = compute_trf(model, 576, print_output=True)
# Out:
# -----------------------------------------------
# UNet wit configuration:     trf100
# Total number of parameters: 31012268
# ...
# layer  type             max_trf_size skip conn.
# ...
#     0  input layer                 1
#
# EncoderBlock
#     1  Conv2d                      3
#     2  BatchNorm2d                 3
#     3  ReLU                        3
#     4  Conv2d                      5
#     5  BatchNorm2d                 5
#     6  ReLU                        5      1 OUT
#     7  MaxPool2d                   6
#
# EncoderBlock
#     8  Conv2d                     10
#     9  BatchNorm2d                10
#    10  ReLU                       10
#    11  Conv2d                     14
#    12  BatchNorm2d                14
#    13  ReLU                       14      2 OUT
#    14  MaxPool2d                  16
#
# EncoderBlock
#    15  Conv2d                     24
#    16  BatchNorm2d                24
#    17  ReLU                       24
#    18  Conv2d                     32
# ...

# %%
config = load_config("trf146")
model = UNet(config)
_ = compute_trf(model, 576, print_output=True)
# Out:
# -----------------------------------------------
# UNet wit configuration:     trf146
# Total number of parameters: 31032960
# ...
# layer  type             max_trf_size skip conn.
# ...
#     0  input layer                 1
#
# EncoderBlock
#     1  Conv2d                      4
#     2  BatchNorm2d                 4
#     3  ReLU                        4
#     4  Conv2d                      7
#     5  BatchNorm2d                 7
#     6  ReLU                        7      1 OUT
#     7  MaxPool2d                   8
#
# EncoderBlock
#     8  Conv2d                     14
#     9  BatchNorm2d                14
#    10  ReLU                       14
#    11  Conv2d                     20
#    12  BatchNorm2d                20
#    13  ReLU                       20      2 OUT
#    14  MaxPool2d                  22
#
# EncoderBlock
#    15  Conv2d                     34
#    16  BatchNorm2d                34
#    17  ReLU                       34
#    18  Conv2d                     46
# ...

# %%
config = load_config("trf204")
model = UNet(config)
_ = compute_trf(model, 576, print_output=True)
# Out:
# -----------------------------------------------
# UNet wit configuration:     trf204
# Total number of parameters: 31042369
# ...
# layer  type             max_trf_size skip conn.
# ...
#     0  input layer                 1
#
# EncoderBlock
#     1  Conv2d                      3
#     2  BatchNorm2d                 3
#     3  ReLU                        3
#     4  Conv2d                      5
#     5  BatchNorm2d                 5
#     6  ReLU                        5      1 OUT
#     7  MaxPool2d                   6
#
# EncoderBlock
#     8  Conv2d                     10
#     9  BatchNorm2d                10
#    10  ReLU                       10
#    11  Conv2d                     14
#    12  BatchNorm2d                14
#    13  ReLU                       14      2 OUT
#    14  MaxPool2d                  16
#
# EncoderBlock
#    15  Conv2d                     24
#    16  BatchNorm2d                24
#    17  ReLU                       24
#    18  Conv2d                     32
# ...

# %%
config = load_config("trf230")
model = UNet(config)
_ = compute_trf(model, 576, print_output=True)
# Out:
# -----------------------------------------------
# UNet wit configuration:     trf230
# Total number of parameters: 31031345
# ...
# layer  type             max_trf_size skip conn.
# ...
#     0  input layer                 1
#
# EncoderBlock
#     1  Conv2d                      6
#     2  BatchNorm2d                 6
#     3  ReLU                        6
#     4  Conv2d                     11
#     5  BatchNorm2d                11
#     6  ReLU                       11      1 OUT
#     7  MaxPool2d                  12
#
# EncoderBlock
#     8  Conv2d                     22
#     9  BatchNorm2d                22
#    10  ReLU                       22
#    11  Conv2d                     32
#    12  BatchNorm2d                32
#    13  ReLU                       32      2 OUT
#    14  MaxPool2d                  34
#
# EncoderBlock
#    15  Conv2d                     54
#    16  BatchNorm2d                54
#    17  ReLU                       54
#    18  Conv2d                     74
# ...

# %%
config = load_config("trf298")
model = UNet(config)
_ = compute_trf(model, 576, print_output=True)
# Out:
# -----------------------------------------------
# UNet wit configuration:     trf298
# Total number of parameters: 31043816
# ...
# layer  type             max_trf_size skip conn.
# ...
#     0  input layer                 1
#
# EncoderBlock
#     1  Conv2d                      4
#     2  BatchNorm2d                 4
#     3  ReLU                        4
#     4  Conv2d                      7
#     5  BatchNorm2d                 7
#     6  ReLU                        7      1 OUT
#     7  MaxPool2d                   8
#
# EncoderBlock
#     8  Conv2d                     14
#     9  BatchNorm2d                14
#    10  ReLU                       14
#    11  Conv2d                     20
#    12  BatchNorm2d                20
#    13  ReLU                       20      2 OUT
#    14  MaxPool2d                  22
#
# EncoderBlock
#    15  Conv2d                     34
#    16  BatchNorm2d                34
#    17  ReLU                       34
#    18  Conv2d                     46
# ...

# %%
config = load_config("trf360")
model = UNet(config)
_ = compute_trf(model, 576, print_output=True)
# Out:
# -----------------------------------------------
# UNet wit configuration:     trf360
# Total number of parameters: 31062482
# ...
# layer  type             max_trf_size skip conn.
# ...
#     0  input layer                 1
#
# EncoderBlock
#     1  Conv2d                      9
#     2  BatchNorm2d                 9
#     3  ReLU                        9
#     4  Conv2d                     17
#     5  BatchNorm2d                17
#     6  ReLU                       17      1 OUT
#     7  MaxPool2d                  18
#
# EncoderBlock
#     8  Conv2d                     34
#     9  BatchNorm2d                34
#    10  ReLU                       34
#    11  Conv2d                     50
#    12  BatchNorm2d                50
#    13  ReLU                       50      2 OUT
#    14  MaxPool2d                  52
#
# EncoderBlock
#    15  Conv2d                     84
#    16  BatchNorm2d                84
#    17  ReLU                       84
#    18  Conv2d                    116
# ...

# %%
config = load_config("trf412")
model = UNet(config)
_ = compute_trf(model, 576, print_output=True)
# Out:
# -----------------------------------------------
# UNet wit configuration:     trf412
# Total number of parameters: 31043945
# ...
# layer  type             max_trf_size skip conn.
# ...
#     0  input layer                 1
#
# EncoderBlock
#     1  Conv2d                      3
#     2  BatchNorm2d                 3
#     3  ReLU                        3
#     4  Conv2d                      5
#     5  BatchNorm2d                 5
#     6  ReLU                        5      1 OUT
#     7  MaxPool2d                   6
#
# EncoderBlock
#     8  Conv2d                     10
#     9  BatchNorm2d                10
#    10  ReLU                       10
#    11  Conv2d                     14
#    12  BatchNorm2d                14
#    13  ReLU                       14      2 OUT
#    14  MaxPool2d                  16
#
# EncoderBlock
#    15  Conv2d                     24
#    16  BatchNorm2d                24
#    17  ReLU                       24
#    18  Conv2d                     32
# ...

# %%
config = load_config("trf486")
model = UNet(config)
_ = compute_trf(model, 576, print_output=True)
# Out:
# -----------------------------------------------
# UNet wit configuration:     trf486
# Total number of parameters: 31027119
# ...
# layer  type             max_trf_size skip conn.
# ...
#     0  input layer                 1
#
# EncoderBlock
#     1  Conv2d                      6
#     2  BatchNorm2d                 6
#     3  ReLU                        6
#     4  Conv2d                     11
#     5  BatchNorm2d                11
#     6  ReLU                       11      1 OUT
#     7  MaxPool2d                  12
#
# EncoderBlock
#     8  Conv2d                     22
#     9  BatchNorm2d                22
#    10  ReLU                       22
#    11  Conv2d                     32
#    12  BatchNorm2d                32
#    13  ReLU                       32      2 OUT
#    14  MaxPool2d                  34
#
# EncoderBlock
#    15  Conv2d                     54
#    16  BatchNorm2d                54
#    17  ReLU                       54
#    18  Conv2d                     74
# ...

# %%
config = load_config("trf570")
model = UNet(config)
_ = compute_trf(model, 576, print_output=True)
# Out:
# -----------------------------------------------
# UNet wit configuration:     trf570
# Total number of parameters: 31041124
# ...
# layer  type             max_trf_size skip conn.
# ...
#     0  input layer                 1
#
# EncoderBlock
#     1  Conv2d                      7
#     2  BatchNorm2d                 7
#     3  ReLU                        7
#     4  Conv2d                     13
#     5  BatchNorm2d                13
#     6  ReLU                       13      1 OUT
#     7  MaxPool2d                  14
#
# EncoderBlock
#     8  Conv2d                     26
#     9  BatchNorm2d                26
#    10  ReLU                       26
#    11  Conv2d                     38
#    12  BatchNorm2d                38
#    13  ReLU                       38      2 OUT
#    14  MaxPool2d                  40
#
# EncoderBlock
#    15  Conv2d                     64
#    16  BatchNorm2d                64
#    17  ReLU                       64
#    18  Conv2d                     88
# ...
