# %%
from unet import UNet
from utils.config import load_config
from utils.metrics import dice_score
from trf import compute_trf
from matplotlib import pyplot as plt
from IPython.display import Image, display
from torch.utils.data import DataLoader
from train import SegmentationDataset
import matplotlib.patches as patches
import numpy as np
import torch
import glob
import os

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## 1. Theoretical Receptive Field
# ### 1.1. Default configuration (i.e. baseline)

# %%
cfg_default = load_config("default")
model_default = UNet(cfg_default).to(device)
rf_default = model_default.output_trfs()
n_params_default = model_default.total_parameters()

# %% [markdown]
# #### 1.1.1. (Max) TRF size of each layer

# %%
_ = compute_trf(model_default, 576, print_output=True)
# Out:
# -----------------------------------------------
# UNet wit configuration:     default
# Total number of parameters: 31042369
# ===============================================
# layer  type             max_trf_size skip conn.
# ===============================================
#     0  input layer                 1
#
# EncoderBlock
#     1  Conv2d                      3
#     2  BatchNorm2d                 3
#     3  ReLU                        3
#     4  Conv2d                      5
#     5  BatchNorm2d                 5
#     6  ReLU                        5      1 OUT
#     7  MaxPool2d                   6
#
# EncoderBlock
#     8  Conv2d                     10
#     9  BatchNorm2d                10
#    10  ReLU                       10
#    11  Conv2d                     14
#    12  BatchNorm2d                14
#    13  ReLU                       14      2 OUT
#    14  MaxPool2d                  16
#
# EncoderBlock
#    15  Conv2d                     24
#    16  BatchNorm2d                24
#    17  ReLU                       24
#    18  Conv2d                     32
#    19  BatchNorm2d                32
#    20  ReLU                       32      3 OUT
#    21  MaxPool2d                  36
#
# EncoderBlock
#    22  Conv2d                     52
#    23  BatchNorm2d                52
#    24  ReLU                       52
#    25  Conv2d                     68
#    26  BatchNorm2d                68
#    27  ReLU                       68      4 OUT
#    28  MaxPool2d                  76
#
# BottleNeck
#    29  Conv2d                    108
#    30  BatchNorm2d               108
#    31  ReLU                      108
#    32  Conv2d                    140
#    33  BatchNorm2d               140
#    34  ReLU                      140
#
# DecoderBlock
#    35  ConvTranspose2d           140
#    36  Conv2d                    156       4 IN
#    37  BatchNorm2d               156
#    38  ReLU                      156
#    39  Conv2d                    172
#    40  BatchNorm2d               172
#    41  ReLU                      172
#
# DecoderBlock
#    42  ConvTranspose2d           172
#    43  Conv2d                    188       3 IN
#    44  BatchNorm2d               188
#    45  ReLU                      188
#    46  Conv2d                    188
#    47  BatchNorm2d               188
#    48  ReLU                      188
#
# DecoderBlock
#    49  ConvTranspose2d           188
#    50  Conv2d                    204       2 IN
#    51  BatchNorm2d               204
#    52  ReLU                      204
#    53  Conv2d                    204
#    54  BatchNorm2d               204
#    55  ReLU                      204
#
# DecoderBlock
#    56  ConvTranspose2d           204
#    57  Conv2d                    204       1 IN
#    58  BatchNorm2d               204
#    59  ReLU                      204
#    60  Conv2d                    204
#    61  BatchNorm2d               204
#    62  ReLU                      204
#    63  Conv2d                    204
# -----------------------------------------------

# %% [markdown]
# #### 1.1.2. Heatmap of TRF size for each pixel in the image
# Value is the square root of the area of the pixel's TRF.

# %%
a = rf_default[:, :, 1, 1] - rf_default[:, :, 0, 1] + 1
b = rf_default[:, :, 1, 0] - rf_default[:, :, 0, 0] + 1
rf_sizes = np.sqrt(np.multiply(a, b))
plt.imshow(rf_sizes, cmap="plasma")
plt.colorbar()
plt.title("RF size of each pixel")
plt.show()

# %% [markdown]
# #### 1.1.3. Some TRFs of specific pixels

# %%
topleft_trf = model_default.pixel_trf(0, 0), (0,0)
topcenter_trf = model_default.pixel_trf(0, 576//2), (0, 576//2)
center_trf = model_default.pixel_trf(576//2, 576//2), (576//2, 576//2)
other_trf = model_default.pixel_trf(123, 354), (123, 354)

fig, axs = plt.subplots(1, 4, figsize=(15, 5))

for i, (trf, pos) in enumerate([topleft_trf, topcenter_trf, center_trf, other_trf]):
    axs[i].imshow(np.zeros((576, 576)))
    axs[i].plot(pos[0], pos[1], 'yo')
    axs[i].set_title(f"TRF of pixel at {pos}")
    start = trf[0, 0], trf[0, 1]
    len_x = trf[1, 0] - trf[0, 0] + 1
    len_y = trf[1, 1] - trf[0, 1] + 1
    patch = patches.Rectangle(start, len_x, len_y, linewidth=1, edgecolor='y', facecolor='none')
    axs[i].add_patch(patch)

plt.show()

# %% [markdown]
# #### 1.1.4. Training results
# These are the loss plots of the two training sets when training for 100 epochs.
# I found experimentally that a batch size of 2 and starting learning rate of 0.01 are optimal for both datasets.

# %%
display(Image(filename='results/default/fetal_head.png'))
display(Image(filename='results/default/breast_cancer.png'))

# %% [markdown]
# #### 1.1.5. Test results
# Lets look at the dice scores on the test sets and inspect some examples.

# %%
fig, axs = plt.subplots(4, 3, figsize=(10, 12))

for n, dataset_name in enumerate(["fetal_head", "breast_cancer"]):
    model_default.load_state_dict(torch.load(f"results/default/{dataset_name}_best_model.pt")["model_state_dict"])
    model_default.eval()

    with torch.no_grad():
        inputs_test = glob.glob(os.path.join(f"data/preprocessed/{dataset_name}/test", "*.png"))
        masks_test = glob.glob(os.path.join(f"data/preprocessed/{dataset_name}/test/masks", "*.png"))

        dataset_test = SegmentationDataset(inputs_test, masks_test)
        dataloader_test = DataLoader(dataset_test, shuffle=True)

        scores = []

        for i, (x, y) in enumerate(dataloader_test):
            x = x.to(device)
            y_true = y.to(device) / 255
            out = torch.sigmoid(model_default(x))
            out = out.detach().cpu().numpy()
            out = (out >= 0.5).astype(int)
            out = np.squeeze(out)

            score = dice_score(out, np.squeeze(y.numpy()))
            scores.append(score)

            if i < 2:
                if n == 0:
                    axs[2*n+i, 0].set_title("Input image")
                    axs[2*n+i, 1].set_title("Ground truth")
                    axs[2*n+i, 2].set_title("Predicted mask")
                axs[2*n+i, 0].imshow(np.squeeze(x.cpu().numpy()), cmap="gray")
                axs[2*n+i, 1].imshow(np.squeeze(y.numpy()), cmap="gray")
                axs[2*n+i, 2].imshow(out, cmap="gray")
    
    print(f"Average test dice score for {dataset_name}: {np.mean(scores):.2f}")
plt.suptitle(f"Random examples from fetal_head and breast_cancer")
plt.show()
# Out:
# Average test dice score for fetal_head: 0.94
# Average test dice score for breast_cancer: 0.43

# %% [markdown]
# ### 1.2. Large TRF (by increasing depth)
# For this configuration I have increased the depth of the network from 4 to 5 (i.e. 5 encoder and 5 decoder blocks), and tuned the channel sizes such that it has approximately the same number of parameters as the baseline model.

# %%
cfg_large_rf_by_depth = load_config("large_rf_by_depth")
model_large_rf_by_depth = UNet(cfg_large_rf_by_depth).to(device)
rf_large_rf_by_depth = model_large_rf_by_depth.output_trfs()
n_params_large_rf_by_depth = model_large_rf_by_depth.total_parameters()

param_ratio = n_params_large_rf_by_depth/n_params_default*100
print(f"{param_ratio:.4f}% of the parameters of the baseline model")
# Out:
# 100.0051% of the parameters of the baseline model

# %% [markdown]
# #### 1.2.1. (Max) TRF size of each layer

# %%
_ = compute_trf(model_large_rf_by_depth, 576, print_output=True)
# Out:
# -----------------------------------------------
# UNet wit configuration:     large_rf_by_depth
# Total number of parameters: 31043945
# ===============================================
# layer  type             max_trf_size skip conn.
# ===============================================
#     0  input layer                 1
#
# EncoderBlock
#     1  Conv2d                      3
#     2  BatchNorm2d                 3
#     3  ReLU                        3
#     4  Conv2d                      5
#     5  BatchNorm2d                 5
#     6  ReLU                        5      1 OUT
#     7  MaxPool2d                   6
#
# EncoderBlock
#     8  Conv2d                     10
#     9  BatchNorm2d                10
#    10  ReLU                       10
#    11  Conv2d                     14
#    12  BatchNorm2d                14
#    13  ReLU                       14      2 OUT
#    14  MaxPool2d                  16
#
# EncoderBlock
#    15  Conv2d                     24
#    16  BatchNorm2d                24
#    17  ReLU                       24
#    18  Conv2d                     32
#    19  BatchNorm2d                32
#    20  ReLU                       32      3 OUT
#    21  MaxPool2d                  36
#
# EncoderBlock
#    22  Conv2d                     52
#    23  BatchNorm2d                52
#    24  ReLU                       52
#    25  Conv2d                     68
#    26  BatchNorm2d                68
#    27  ReLU                       68      4 OUT
#    28  MaxPool2d                  76
#
# EncoderBlock
#    29  Conv2d                    108
#    30  BatchNorm2d               108
#    31  ReLU                      108
#    32  Conv2d                    140
#    33  BatchNorm2d               140
#    34  ReLU                      140      5 OUT
#    35  MaxPool2d                 156
#
# BottleNeck
#    36  Conv2d                    220
#    37  BatchNorm2d               220
#    38  ReLU                      220
#    39  Conv2d                    284
#    40  BatchNorm2d               284
#    41  ReLU                      284
#
# DecoderBlock
#    42  ConvTranspose2d           284
#    43  Conv2d                    316       5 IN
#    44  BatchNorm2d               316
#    45  ReLU                      316
#    46  Conv2d                    348
#    47  BatchNorm2d               348
#    48  ReLU                      348
#
# DecoderBlock
#    49  ConvTranspose2d           348
#    50  Conv2d                    380       4 IN
#    51  BatchNorm2d               380
#    52  ReLU                      380
#    53  Conv2d                    380
#    54  BatchNorm2d               380
#    55  ReLU                      380
#
# DecoderBlock
#    56  ConvTranspose2d           380
#    57  Conv2d                    412       3 IN
#    58  BatchNorm2d               412
#    59  ReLU                      412
#    60  Conv2d                    412
#    61  BatchNorm2d               412
#    62  ReLU                      412
#
# DecoderBlock
#    63  ConvTranspose2d           412
#    64  Conv2d                    412       2 IN
#    65  BatchNorm2d               412
#    66  ReLU                      412
#    67  Conv2d                    412
#    68  BatchNorm2d               412
#    69  ReLU                      412
#
# DecoderBlock
#    70  ConvTranspose2d           412
#    71  Conv2d                    412       1 IN
#    72  BatchNorm2d               412
#    73  ReLU                      412
#    74  Conv2d                    412
#    75  BatchNorm2d               412
#    76  ReLU                      412
#    77  Conv2d                    412
# -----------------------------------------------

# %% [markdown]
# #### 1.2.2. Heatmap of TRF size for each pixel in the image
# Value is the square root of the area of the pixel's TRF.

# %%
a = rf_large_rf_by_depth[:, :, 1, 1] - rf_large_rf_by_depth[:, :, 0, 1] + 1
b = rf_large_rf_by_depth[:, :, 1, 0] - rf_large_rf_by_depth[:, :, 0, 0] + 1
rf_sizes = np.sqrt(np.multiply(a, b))
plt.imshow(rf_sizes, cmap="plasma")
plt.colorbar()
plt.title("RF size of each pixel")
plt.show()

# %% [markdown]
# #### 1.2.3. Some TRFs of specific pixels

# %%
topleft_trf = model_large_rf_by_depth.pixel_trf(0, 0), (0,0)
topcenter_trf = model_large_rf_by_depth.pixel_trf(0, 576//2), (0, 576//2)
center_trf = model_large_rf_by_depth.pixel_trf(576//2, 576//2), (576//2, 576//2)
other_trf = model_large_rf_by_depth.pixel_trf(123, 354), (123, 354)

fig, axs = plt.subplots(1, 4, figsize=(15, 5))

for i, (trf, pos) in enumerate([topleft_trf, topcenter_trf, center_trf, other_trf]):
    axs[i].imshow(np.zeros((576, 576)))
    axs[i].plot(pos[0], pos[1], 'yo')
    axs[i].set_title(f"TRF of pixel at {pos}")
    start = trf[0, 0], trf[0, 1]
    len_x = trf[1, 0] - trf[0, 0] + 1
    len_y = trf[1, 1] - trf[0, 1] + 1
    patch = patches.Rectangle(start, len_x, len_y, linewidth=1, edgecolor='y', facecolor='none')
    axs[i].add_patch(patch)

plt.show()

# %% [markdown]
# #### 1.2.4. Training results
# These are the loss plots of the two training sets when training for 100 epochs.
# I found experimentally that a batch size of 2 and starting learning rate of 0.01 are optimal for both datasets.

# %%
display(Image(filename='results/large_rf_by_depth/fetal_head.png'))
display(Image(filename='results/large_rf_by_depth/breast_cancer.png'))

# %% [markdown]
# #### 1.2.5. Test results

# %%
for n, dataset_name in enumerate(["fetal_head", "breast_cancer"]):
    model_large_rf_by_depth.load_state_dict(torch.load(f"results/large_rf_by_depth/{dataset_name}_best_model.pt")["model_state_dict"])
    model_large_rf_by_depth.eval()

    with torch.no_grad():
        inputs_test = glob.glob(os.path.join(f"data/preprocessed/{dataset_name}/test", "*.png"))
        masks_test = glob.glob(os.path.join(f"data/preprocessed/{dataset_name}/test/masks", "*.png"))

        dataset_test = SegmentationDataset(inputs_test, masks_test)
        dataloader_test = DataLoader(dataset_test, shuffle=True)

        scores = []

        for i, (x, y) in enumerate(dataloader_test):
            x = x.to(device)
            y_true = y.to(device) / 255
            out = torch.sigmoid(model_large_rf_by_depth(x))
            out = out.detach().cpu().numpy()
            out = (out >= 0.5).astype(int)
            out = np.squeeze(out)

            score = dice_score(out, np.squeeze(y.numpy()))
            scores.append(score)
    
    print(f"Average test dice score for {dataset_name}: {np.mean(scores):.2f}")
# Out:
# Average test dice score for fetal_head: 0.96
# Average test dice score for breast_cancer: 0.54

# %% [markdown]
# ## 1.3. Large TRF (by tuning hyperparameters)
# Increased convolution kernel from 3 to 4, changed channel sizes to keep same number of parameters.

# %%
cfg_large_rf_by_hparams = load_config("large_rf_by_hparams")
model_large_rf_by_hparams = UNet(cfg_large_rf_by_hparams).to(device)
rf_large_rf_by_hparams = model_large_rf_by_hparams.output_trfs()
n_params_large_rf_by_hparams = model_large_rf_by_hparams.total_parameters()

param_ratio = n_params_large_rf_by_hparams/n_params_default*100
print(f"{param_ratio:.4f}% of the parameters of the baseline model")
# Out:
# 100.0047% of the parameters of the baseline model

# %% [markdown]
# #### 1.3.1. (Max) TRF size of each layer

# %%
_ = compute_trf(model_large_rf_by_hparams, 576, print_output=True)
# Out:
# -----------------------------------------------
# UNet wit configuration:     large_rf_by_hparams
# Total number of parameters: 31043816
# ===============================================
# layer  type             max_trf_size skip conn.
# ===============================================
#     0  input layer                 1
#
# EncoderBlock
#     1  Conv2d                      4
#     2  BatchNorm2d                 4
#     3  ReLU                        4
#     4  Conv2d                      7
#     5  BatchNorm2d                 7
#     6  ReLU                        7      1 OUT
#     7  MaxPool2d                   8
#
# EncoderBlock
#     8  Conv2d                     14
#     9  BatchNorm2d                14
#    10  ReLU                       14
#    11  Conv2d                     20
#    12  BatchNorm2d                20
#    13  ReLU                       20      2 OUT
#    14  MaxPool2d                  22
#
# EncoderBlock
#    15  Conv2d                     34
#    16  BatchNorm2d                34
#    17  ReLU                       34
#    18  Conv2d                     46
#    19  BatchNorm2d                46
#    20  ReLU                       46      3 OUT
#    21  MaxPool2d                  50
#
# EncoderBlock
#    22  Conv2d                     74
#    23  BatchNorm2d                74
#    24  ReLU                       74
#    25  Conv2d                     98
#    26  BatchNorm2d                98
#    27  ReLU                       98      4 OUT
#    28  MaxPool2d                 106
#
# BottleNeck
#    29  Conv2d                    154
#    30  BatchNorm2d               154
#    31  ReLU                      154
#    32  Conv2d                    202
#    33  BatchNorm2d               202
#    34  ReLU                      202
#
# DecoderBlock
#    35  ConvTranspose2d           202
#    36  Conv2d                    234       4 IN
#    37  BatchNorm2d               234
#    38  ReLU                      234
#    39  Conv2d                    250
#    40  BatchNorm2d               250
#    41  ReLU                      250
#
# DecoderBlock
#    42  ConvTranspose2d           250
#    43  Conv2d                    266       3 IN
#    44  BatchNorm2d               266
#    45  ReLU                      266
#    46  Conv2d                    282
#    47  BatchNorm2d               282
#    48  ReLU                      282
#
# DecoderBlock
#    49  ConvTranspose2d           282
#    50  Conv2d                    282       2 IN
#    51  BatchNorm2d               282
#    52  ReLU                      282
#    53  Conv2d                    298
#    54  BatchNorm2d               298
#    55  ReLU                      298
#
# DecoderBlock
#    56  ConvTranspose2d           298
#    57  Conv2d                    298       1 IN
#    58  BatchNorm2d               298
#    59  ReLU                      298
#    60  Conv2d                    298
#    61  BatchNorm2d               298
#    62  ReLU                      298
#    63  Conv2d                    298
# -----------------------------------------------

# %% [markdown]
# #### 1.3.2. Heatmap of TRF size for each pixel in the image
# Value is the square root of the area of the pixel's TRF.

# %%
a = rf_large_rf_by_hparams[:, :, 1, 1] - rf_large_rf_by_hparams[:, :, 0, 1] + 1
b = rf_large_rf_by_hparams[:, :, 1, 0] - rf_large_rf_by_hparams[:, :, 0, 0] + 1
rf_sizes = np.sqrt(np.multiply(a, b))
plt.imshow(rf_sizes, cmap="plasma")
plt.colorbar()
plt.title("RF size of each pixel")
plt.show()

# %% [markdown]
# #### 1.3.3. Some TRFs of specific pixels

# %%
topleft_trf = model_large_rf_by_hparams.pixel_trf(0, 0), (0,0)
topcenter_trf = model_large_rf_by_hparams.pixel_trf(0, 576//2), (0, 576//2)
center_trf = model_large_rf_by_hparams.pixel_trf(576//2, 576//2), (576//2, 576//2)
other_trf = model_large_rf_by_hparams.pixel_trf(123, 354), (123, 354)

fig, axs = plt.subplots(1, 4, figsize=(15, 5))

for i, (trf, pos) in enumerate([topleft_trf, topcenter_trf, center_trf, other_trf]):
    axs[i].imshow(np.zeros((576, 576)))
    axs[i].plot(pos[0], pos[1], 'yo')
    axs[i].set_title(f"TRF of pixel at {pos}")
    start = trf[0, 0], trf[0, 1]
    len_x = trf[1, 0] - trf[0, 0] + 1
    len_y = trf[1, 1] - trf[0, 1] + 1
    patch = patches.Rectangle(start, len_x, len_y, linewidth=1, edgecolor='y', facecolor='none')
    axs[i].add_patch(patch)

plt.show()

# %% [markdown]
# #### 1.3.4. Training results
# These are the loss plots of the two training sets when training for 100 epochs.
# I found experimentally that a batch size of 2 and starting learning rate of 0.01 are optimal for both datasets.

# %%
display(Image(filename='results/large_rf_by_hparams/fetal_head.png'))
display(Image(filename='results/large_rf_by_hparams/breast_cancer.png'))

# %% [markdown]
# #### 1.3.5. Test results

# %%
for n, dataset_name in enumerate(["fetal_head", "breast_cancer"]):
    model_large_rf_by_hparams.load_state_dict(torch.load(f"results/large_rf_by_hparams/{dataset_name}_best_model.pt")["model_state_dict"])
    model_large_rf_by_hparams.eval()

    with torch.no_grad():
        inputs_test = glob.glob(os.path.join(f"data/preprocessed/{dataset_name}/test", "*.png"))
        masks_test = glob.glob(os.path.join(f"data/preprocessed/{dataset_name}/test/masks", "*.png"))

        dataset_test = SegmentationDataset(inputs_test, masks_test)
        dataloader_test = DataLoader(dataset_test, shuffle=True)

        scores = []

        for i, (x, y) in enumerate(dataloader_test):
            x = x.to(device)
            y_true = y.to(device) / 255
            out = torch.sigmoid(model_large_rf_by_hparams(x))
            out = out.detach().cpu().numpy()
            out = (out >= 0.5).astype(int)
            out = np.squeeze(out)

            score = dice_score(out, np.squeeze(y.numpy()))
            scores.append(score)
    
    print(f"Average test dice score for {dataset_name}: {np.mean(scores):.2f}")
# Out:
# Average test dice score for fetal_head: 0.96
# Average test dice score for breast_cancer: 0.56

# %% [markdown]
# ## 1.4. Small TRF (by decreasing depth)
# For this configuration I have increased the depth of the network from 4 to 3 (i.e. 3 encoder and 3 decoder blocks), and tuned the channel sizes such that it has approximately the same number of parameters as the baseline model.

# %%
cfg_small_rf_by_depth = load_config("small_rf_by_depth")
model_small_rf_by_depth = UNet(cfg_small_rf_by_depth).to(device)
rf_small_rf_by_depth = model_small_rf_by_depth.output_trfs()
n_params_small_rf_by_depth = model_small_rf_by_depth.total_parameters()

param_ratio = n_params_small_rf_by_depth/n_params_default*100
print(f"{param_ratio:.4f}% of the parameters of the baseline model")
# Out:
# 100.0374% of the parameters of the baseline model

# %% [markdown]
# #### 1.4.1. (Max) TRF size of each layer

# %%
_ = compute_trf(model_small_rf_by_depth, 576, print_output=True)
# Out:
# -----------------------------------------------
# UNet wit configuration:     small_rf_by_depth
# Total number of parameters: 31053965
# ===============================================
# layer  type             max_trf_size skip conn.
# ===============================================
#     0  input layer                 1
#
# EncoderBlock
#     1  Conv2d                      3
#     2  BatchNorm2d                 3
#     3  ReLU                        3
#     4  Conv2d                      5
#     5  BatchNorm2d                 5
#     6  ReLU                        5      1 OUT
#     7  MaxPool2d                   6
#
# EncoderBlock
#     8  Conv2d                     10
#     9  BatchNorm2d                10
#    10  ReLU                       10
#    11  Conv2d                     14
#    12  BatchNorm2d                14
#    13  ReLU                       14      2 OUT
#    14  MaxPool2d                  16
#
# EncoderBlock
#    15  Conv2d                     24
#    16  BatchNorm2d                24
#    17  ReLU                       24
#    18  Conv2d                     32
#    19  BatchNorm2d                32
#    20  ReLU                       32      3 OUT
#    21  MaxPool2d                  36
#
# BottleNeck
#    22  Conv2d                     52
#    23  BatchNorm2d                52
#    24  ReLU                       52
#    25  Conv2d                     68
#    26  BatchNorm2d                68
#    27  ReLU                       68
#
# DecoderBlock
#    28  ConvTranspose2d            68
#    29  Conv2d                     76       3 IN
#    30  BatchNorm2d                76
#    31  ReLU                       76
#    32  Conv2d                     84
#    33  BatchNorm2d                84
#    34  ReLU                       84
#
# DecoderBlock
#    35  ConvTranspose2d            84
#    36  Conv2d                     92       2 IN
#    37  BatchNorm2d                92
#    38  ReLU                       92
#    39  Conv2d                     92
#    40  BatchNorm2d                92
#    41  ReLU                       92
#
# DecoderBlock
#    42  ConvTranspose2d            92
#    43  Conv2d                    100       1 IN
#    44  BatchNorm2d               100
#    45  ReLU                      100
#    46  Conv2d                    100
#    47  BatchNorm2d               100
#    48  ReLU                      100
#    49  Conv2d                    100
# -----------------------------------------------

# %% [markdown]
# #### 1.4.2. Heatmap of TRF size for each pixel in the image
# Value is the square root of the area of the pixel's TRF.

# %%
a = rf_small_rf_by_depth[:, :, 1, 1] - rf_small_rf_by_depth[:, :, 0, 1] + 1
b = rf_small_rf_by_depth[:, :, 1, 0] - rf_small_rf_by_depth[:, :, 0, 0] + 1
rf_sizes = np.sqrt(np.multiply(a, b))
plt.imshow(rf_sizes, cmap="plasma")
plt.colorbar()
plt.title("RF size of each pixel")
plt.show()

# %% [markdown]
# #### 1.4.3. Some TRFs of specific pixels

# %%
topleft_trf = model_small_rf_by_depth.pixel_trf(0, 0), (0,0)
topcenter_trf = model_small_rf_by_depth.pixel_trf(0, 576//2), (0, 576//2)
center_trf = model_small_rf_by_depth.pixel_trf(576//2, 576//2), (576//2, 576//2)
other_trf = model_small_rf_by_depth.pixel_trf(123, 354), (123, 354)

fig, axs = plt.subplots(1, 4, figsize=(15, 5))

for i, (trf, pos) in enumerate([topleft_trf, topcenter_trf, center_trf, other_trf]):
    axs[i].imshow(np.zeros((576, 576)))
    axs[i].plot(pos[0], pos[1], 'yo')
    axs[i].set_title(f"TRF of pixel at {pos}")
    start = trf[0, 0], trf[0, 1]
    len_x = trf[1, 0] - trf[0, 0] + 1
    len_y = trf[1, 1] - trf[0, 1] + 1
    patch = patches.Rectangle(start, len_x, len_y, linewidth=1, edgecolor='y', facecolor='none')
    axs[i].add_patch(patch)

plt.show()

# %% [markdown]
# #### 1.4.4. Training results
# These are the loss plots of the two training sets when training for 100 epochs.
# I found experimentally that a batch size of 2 and starting learning rate of 0.01 are optimal for both datasets.

# %%
display(Image(filename='results/small_rf_by_depth/fetal_head.png'))
display(Image(filename='results/small_rf_by_depth/breast_cancer.png'))

# %% [markdown]
# #### 1.4.5. Test results

# %%
for n, dataset_name in enumerate(["fetal_head", "breast_cancer"]):
    model_small_rf_by_depth.load_state_dict(torch.load(f"results/small_rf_by_depth/{dataset_name}_best_model.pt")["model_state_dict"])
    model_small_rf_by_depth.eval()

    with torch.no_grad():
        inputs_test = glob.glob(os.path.join(f"data/preprocessed/{dataset_name}/test", "*.png"))
        masks_test = glob.glob(os.path.join(f"data/preprocessed/{dataset_name}/test/masks", "*.png"))

        dataset_test = SegmentationDataset(inputs_test, masks_test)
        dataloader_test = DataLoader(dataset_test, shuffle=True)

        scores = []

        for i, (x, y) in enumerate(dataloader_test):
            x = x.to(device)
            y_true = y.to(device) / 255
            out = torch.sigmoid(model_small_rf_by_depth(x))
            out = out.detach().cpu().numpy()
            out = (out >= 0.5).astype(int)
            out = np.squeeze(out)

            score = dice_score(out, np.squeeze(y.numpy()))
            scores.append(score)
    
    print(f"Average test dice score for {dataset_name}: {np.mean(scores):.2f}")
# Out:
# Average test dice score for fetal_head: 0.88
# Average test dice score for breast_cancer: 0.31

# %% [markdown]
# ## 1.5. Small TRF (by tuning hyperparameters)
# Increased convolution kernel from 3 to 2, changed channel sizes to keep same number of parameters.

# %%
cfg_small_rf_by_hparams = load_config("small_rf_by_hparams")
model_small_rf_by_hparams = UNet(cfg_small_rf_by_hparams).to(device)
rf_small_rf_by_hparams = model_small_rf_by_hparams.output_trfs()
n_params_small_rf_by_hparams = model_small_rf_by_hparams.total_parameters()

param_ratio = n_params_small_rf_by_hparams/n_params_default*100
print(f"{param_ratio:.4f}% of the parameters of the baseline model")
# Out:
# 100.0012% of the parameters of the baseline model

# %% [markdown]
# #### 1.5.1. (Max) TRF size of each layer

# %%
_ = compute_trf(model_small_rf_by_hparams, 576, print_output=True)
# Out:
# -----------------------------------------------
# UNet wit configuration:     large_rf_by_hparams
# Total number of parameters: 31042732
# ===============================================
# layer  type             max_trf_size skip conn.
# ===============================================
#     0  input layer                 1
#
# EncoderBlock
#     1  Conv2d                      2
#     2  BatchNorm2d                 2
#     3  ReLU                        2
#     4  Conv2d                      3
#     5  BatchNorm2d                 3
#     6  ReLU                        3      1 OUT
#     7  MaxPool2d                   4
#
# EncoderBlock
#     8  Conv2d                      6
#     9  BatchNorm2d                 6
#    10  ReLU                        6
#    11  Conv2d                      8
#    12  BatchNorm2d                 8
#    13  ReLU                        8      2 OUT
#    14  MaxPool2d                  10
#
# EncoderBlock
#    15  Conv2d                     14
#    16  BatchNorm2d                14
#    17  ReLU                       14
#    18  Conv2d                     18
#    19  BatchNorm2d                18
#    20  ReLU                       18      3 OUT
#    21  MaxPool2d                  22
#
# EncoderBlock
#    22  Conv2d                     30
#    23  BatchNorm2d                30
#    24  ReLU                       30
#    25  Conv2d                     38
#    26  BatchNorm2d                38
#    27  ReLU                       38      4 OUT
#    28  MaxPool2d                  46
#
# BottleNeck
#    29  Conv2d                     62
#    30  BatchNorm2d                62
#    31  ReLU                       62
#    32  Conv2d                     78
#    33  BatchNorm2d                78
#    34  ReLU                       78
#
# DecoderBlock
#    35  ConvTranspose2d            78
#    36  Conv2d                     94       4 IN
#    37  BatchNorm2d                94
#    38  ReLU                       94
#    39  Conv2d                     94
#    40  BatchNorm2d                94
#    41  ReLU                       94
#
# DecoderBlock
#    42  ConvTranspose2d            94
#    43  Conv2d                    110       3 IN
#    44  BatchNorm2d               110
#    45  ReLU                      110
#    46  Conv2d                    110
#    47  BatchNorm2d               110
#    48  ReLU                      110
#
# DecoderBlock
#    49  ConvTranspose2d           110
#    50  Conv2d                    110       2 IN
#    51  BatchNorm2d               110
#    52  ReLU                      110
#    53  Conv2d                    110
#    54  BatchNorm2d               110
#    55  ReLU                      110
#
# DecoderBlock
#    56  ConvTranspose2d           110
#    57  Conv2d                    110       1 IN
#    58  BatchNorm2d               110
#    59  ReLU                      110
#    60  Conv2d                    110
#    61  BatchNorm2d               110
#    62  ReLU                      110
#    63  Conv2d                    110
# -----------------------------------------------

# %% [markdown]
# #### 1.5.2. Heatmap of TRF size for each pixel in the image
# Value is the square root of the area of the pixel's TRF.

# %%
a = rf_small_rf_by_hparams[:, :, 1, 1] - rf_small_rf_by_hparams[:, :, 0, 1] + 1
b = rf_small_rf_by_hparams[:, :, 1, 0] - rf_small_rf_by_hparams[:, :, 0, 0] + 1
rf_sizes = np.sqrt(np.multiply(a, b))
plt.imshow(rf_sizes, cmap="plasma")
plt.colorbar()
plt.title("RF size of each pixel")
plt.show()

# %% [markdown]
# #### 1.5.3. Some TRFs of specific pixels

# %%
topleft_trf = model_small_rf_by_depth.pixel_trf(0, 0), (0,0)
topcenter_trf = model_small_rf_by_depth.pixel_trf(0, 576//2), (0, 576//2)
center_trf = model_small_rf_by_depth.pixel_trf(576//2, 576//2), (576//2, 576//2)
other_trf = model_small_rf_by_depth.pixel_trf(123, 354), (123, 354)

fig, axs = plt.subplots(1, 4, figsize=(15, 5))

for i, (trf, pos) in enumerate([topleft_trf, topcenter_trf, center_trf, other_trf]):
    axs[i].imshow(np.zeros((576, 576)))
    axs[i].plot(pos[0], pos[1], 'yo')
    axs[i].set_title(f"TRF of pixel at {pos}")
    start = trf[0, 0], trf[0, 1]
    len_x = trf[1, 0] - trf[0, 0] + 1
    len_y = trf[1, 1] - trf[0, 1] + 1
    patch = patches.Rectangle(start, len_x, len_y, linewidth=1, edgecolor='y', facecolor='none')
    axs[i].add_patch(patch)

plt.show()

# %% [markdown]
# #### 1.4.4. Training results
# These are the loss plots of the two training sets when training for 100 epochs.
# I found experimentally that a batch size of 2 and starting learning rate of 0.01 are optimal for both datasets.

# %%
display(Image(filename='results/small_rf_by_hparams/fetal_head.png'))
display(Image(filename='results/small_rf_by_hparams/breast_cancer.png'))

# %% [markdown]
# #### 1.4.5. Test results

# %%
for n, dataset_name in enumerate(["fetal_head", "breast_cancer"]):
    model_small_rf_by_hparams.load_state_dict(torch.load(f"results/small_rf_by_hparams/{dataset_name}_best_model.pt")["model_state_dict"])
    model_small_rf_by_hparams.eval()

    with torch.no_grad():
        inputs_test = glob.glob(os.path.join(f"data/preprocessed/{dataset_name}/test", "*.png"))
        masks_test = glob.glob(os.path.join(f"data/preprocessed/{dataset_name}/test/masks", "*.png"))

        dataset_test = SegmentationDataset(inputs_test, masks_test)
        dataloader_test = DataLoader(dataset_test, shuffle=True)

        scores = []

        for i, (x, y) in enumerate(dataloader_test):
            x = x.to(device)
            y_true = y.to(device) / 255
            out = torch.sigmoid(model_small_rf_by_hparams(x))
            out = out.detach().cpu().numpy()
            out = (out >= 0.5).astype(int)
            out = np.squeeze(out)

            score = dice_score(out, np.squeeze(y.numpy()))
            scores.append(score)
    
    print(f"Average test dice score for {dataset_name}: {np.mean(scores):.2f}")
# Out:
# Average test dice score for fetal_head: 0.87
# Average test dice score for breast_cancer: 0.29

# %% [markdown]
# ### 1.6. Overview of results and answering first research question
#
# | **Model**                    | **No. of parameters** | **TRF size** | **breast_cancer test Dice score** | **fetal_head test Dice score** |
# |------------------------------|-----------------------|--------------|:---------------------------------:|:------------------------------:|
# | baseline                     |              31042369 |          204 |                              0.43 |                           0.94 |
# | small TRF by depth           |              31053965 |          100 |                              0.31 |                           0.88 |
# | small TRF by hyperparameters |              31042732 |          110 |                              0.29 |                           0.87 |
# | large TRF by depth           |              31043945 |          412 |                              0.54 |                           0.96 |
# | large TRF by hyperparameters |              31043816 |          298 |                              0.56 |                           0.96 |
#
# So to answer the first research question of "We want to know whether theoretical receptive field of a Unet plays a role in efficiency of Unet network? What if receptive field of a Unet is decreased holding number of parameters same?", we can say that when keeping the number of parameters the same, increasing the TRF size leads to better performance and deacresing the TRF size leads to worse performance.
